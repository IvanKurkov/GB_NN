# %%
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import VGG16, EfficientNetB0, ResNet101, DenseNet121
import numpy as np
from PIL import Image
import tensorflow as tf


# Это наша метрика на Tensorflow

def dice_coef(y_true, y_pred):
    return (2. * tf.math.reduce_sum(y_true * y_pred) + 1.) / (tf.math.reduce_sum(y_true) + tf.math.reduce_sum(y_pred) + 1.)

# %%
import cv2

# %% [markdown]
# Читаем имена файлов из рабочего каталога

# %%
images = []
segments = []
from skimage.io import imread
import os
image_size = (128,128)
for root, dirs, files in os.walk(os.path.join('PH2 Dataset images')):
    if root.endswith('_Dermoscopic_Image'):
        images.append(image.load_img(os.path.join(root, files[0]) ,target_size = image_size))
    if root.endswith('_lesion'):
        segments.append(image.load_img(os.path.join(root, files[0]),target_size = image_size))

# %% [markdown]
# #Загружаем и уменьшаем картинки
#
# можно обойтись исходным рахзмером или взять другой
#
# ВАЖНО - размер по обеим сторонам должен делиться на 2 несколько раз (сколько будет сжатий кадра)

# %% [markdown]
# Посмотрели на входные кадры

# %%
plt.imshow(images[2].convert('RGBA'))
plt.show()

# %% [markdown]
# Посмотрим на цели

# %%
plt.imshow(segments[2].convert('RGBA'))
plt.show()

# %% [markdown]
# #Создаём обучающую выборку

# %% [markdown]
# Собираем входные примеры:

# %%
xTrain_Test = []

for img in images:
    x = np.array(img)
    xTrain_Test.append(x)

xTrain_Test = np.array(xTrain_Test)

# %%
print(xTrain_Test.shape)
# Out:
# (200, 128, 128, 3)

# %% [markdown]
# Порстроим цвета , воспринимаемого диапазона для сегментированной картинки - это результат разметки, которую принесет разметчик

# %% [markdown]
# Color Coding:
#
# Car	  ( 0, 0, 0)	Object
#
# Void	( 255,255, 255)	Void

# %% [markdown]
# Делаем конвертер в one-hot_encoding для выходных примеров
#
#   - каждому классу (цвету) ставим в соответствие свою карту ответов y_cat, где 1 , если цвет этого пикселя равен номеру карты и 0 в противном случае
#   - для визуализации строим карту цветов y_ind, где пиксель содержит номер цвета

# %%
def Color2index(y):
  #y - входное изображение разметки (УхХхС - цветное )
  # карту цветов y_ind
  # карту ответов one-hot-encoding y_cat

  # список актуальных цветов разметки
    arr_col=[[0,0,0],[255,255,255]]
    y_ind = np.zeros((y.shape[0],y.shape[1]))
    y_cat = np.zeros((y.shape[0],y.shape[1], len(arr_col)))
    i = 1
    for i_color in arr_col:
        #найдем все точки цвета i_color
        ind_i = np.where((y[:,:,0] == i_color[0]) & (y[:,:,1] == i_color[1]) & (y[:,:,2] == i_color[2]))

        y_ind[ind_i[0],ind_i[1]] = i
        y_cat[ind_i[0],ind_i[1], i-1] = 1 
        i += 1
  
    return y_cat, y_ind, i-1
cat_yi,ind_yi,h = Color2index(image.img_to_array(segments[0]))
plt.imshow(ind_yi.astype(float)/h)
plt.show()

# %% [markdown]
# Проверяем максимальное значение слоя 1 (по нашей схеме должна быть 1)

# %%
np.max(cat_yi[:,:,1] )
# Out:
# 1.0

# %% [markdown]
# Оценим размер карты ответа:
#   - число каналов равно числу классов
#   - размер карты равер размеру картинки входа

# %%
cat_yi.shape
# Out:
# (128, 128, 2)

# %% [markdown]
# Сегментированную картинку в  One hot encoding (разметка на 2 класса)**

# %%
yTrain_Test = []

for seg in segments:
    y_cat,_,_ = Color2index(image.img_to_array(seg))
    yTrain_Test.append(y_cat)

yTrain_Test = np.array(yTrain_Test)

# %%
print(yTrain_Test.shape)
# Out:
# (200, 128, 128, 2)

# %%
n = 1
plt.imshow(segments[n].convert('RGBA'))
plt.show()
img = yTrain_Test[n][:,:,n]
plt.imshow(img.astype(float))
plt.show()

# %% [markdown]
# Делим на тест и трейн по числу N

# %%
N = 150
yTrain = yTrain_Test[:N,:,:,:]
xTrain = xTrain_Test[:N,:,:,:]

yTest = yTrain_Test[N:,:,:,:]
xTest = xTrain_Test[N:,:,:,:]

# %%
yTest.shape
# Out:
# (50, 128, 128, 2)

# %%
print(xTrain.shape)
print(yTrain.shape)
# Out:
# (150, 128, 128, 3)
# (150, 128, 128, 2)

# %% [markdown]
# #Создаём и обучаем U-net

# %%
from tensorflow.keras.utils import plot_model

# %% [markdown]
# **Unet**

# %%
def Unet(num_classes = 2, input_shape= (128, 128, 3)):
  #num_classes = 2, - число классов ответа
  #input_shape= (112, 160, 3) - размер входной картинки

  #model - выходная модель

    img_input = Input(input_shape) # вход модели

    # Block 1
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_1_out = Activation('relu')(x)

    x = MaxPooling2D()(block_1_out) # 56x80

    # Block 2
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_2_out = Activation('relu')(x)

    x = MaxPooling2D()(block_2_out) # 28x40

    # Block 3
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_3_out = Activation('relu')(x)

    x = MaxPooling2D()(block_3_out) #14x20

    # Block 4
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_4_out = Activation('relu')(x)

    x = MaxPooling2D()(block_4_out) # 7x10

    # Block 5
    x = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv3')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 1
    x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x) # 7x10
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_4_out])
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x) #28x40
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x) # 56x80
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x) # 112x160
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_1_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # слой классификатор
    x = Conv2D(num_classes, (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(img_input, x)
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[dice_coef])
    model.summary()
    return model

# %%
modelC = Unet(2, (128, 128, 3))

plot_model(modelC, to_file='modelC.png')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['block1_conv1[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['activation_25[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 64  256        ['block1_conv2[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_26[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_27[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_28[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 256)  1024       ['block3_conv1[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_29[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 256)  1024       ['block3_conv2[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_30[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 256)  1024       ['block3_conv3[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_31[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_31[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 512)  2048       ['block4_conv1[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_32[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 512)  2048       ['block4_conv2[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_33[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 512)  2048       ['block4_conv3[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_34[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 512)   0           ['activation_34[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 512)   2048        ['block5_conv1[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_35[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 512)   2048        ['block5_conv2[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_36[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 512)   2048        ['block5_conv3[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 512)  1049088    ['activation_37[0][0]']
#  spose)
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_38[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['activation_38[0][0]',
#                                 )                                 'activation_34[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_40[0][0]']
#  spose)
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_41[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['activation_41[0][0]',
#                                                                   'activation_31[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_43[0][0]']
#  spose)
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 128)  512        ['conv2d_transpose_6[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_44[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['activation_44[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_46[0][0]']
#  spose)                         )
#
#  batch_normalization_47 (BatchN  (None, 128, 128, 64  256        ['conv2d_transpose_7[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['activation_47[0][0]',
#                                 8)                                'activation_26[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  36928       ['activation_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 2)  1154        ['activation_49[0][0]']
#
# ==================================================================================================
# Total params: 25,884,162
# Trainable params: 25,869,954
# Non-trainable params: 14,208
# __________________________________________________________________________________________________

# %% [markdown]
# Обучаем модель

# %%
history = modelC.fit(xTrain, yTrain, epochs=10, batch_size=20, validation_data=(xTrain, yTrain))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 14s 831ms/step - loss: 0.5540 - dice_coef: 0.6407 - val_loss: 0.8222 - val_dice_coef: 0.7257
# Epoch 2/10
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3534 - dice_coef: 0.7522 - val_loss: 0.6537 - val_dice_coef: 0.7326
# Epoch 3/10
# 8/8 [==============================] - 2s 302ms/step - loss: 0.2588 - dice_coef: 0.8110 - val_loss: 0.5566 - val_dice_coef: 0.7398
# Epoch 4/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1946 - dice_coef: 0.8537 - val_loss: 0.5050 - val_dice_coef: 0.7427
# Epoch 5/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1703 - dice_coef: 0.8757 - val_loss: 0.4785 - val_dice_coef: 0.7470
# Epoch 6/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1509 - dice_coef: 0.8909 - val_loss: 0.4611 - val_dice_coef: 0.7508
# Epoch 7/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1415 - dice_coef: 0.9000 - val_loss: 0.4546 - val_dice_coef: 0.7561
# Epoch 8/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1278 - dice_coef: 0.9090 - val_loss: 0.4228 - val_dice_coef: 0.7586
# Epoch 9/10
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1140 - dice_coef: 0.9178 - val_loss: 0.4270 - val_dice_coef: 0.7569
# Epoch 10/10
# 8/8 [==============================] - 2s 302ms/step - loss: 0.1145 - dice_coef: 0.9207 - val_loss: 0.4419 - val_dice_coef: 0.7587

# %%
plt.plot(history.history['val_dice_coef'],label = 'test')
plt.plot(history.history['dice_coef'],label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.grid()
plt.title('history of train and val')
plt.show()

# %% [markdown]
# Тест модели

# %%
history = modelC.fit(xTrain, yTrain, epochs=100, batch_size=40, validation_data=(xTest, yTest))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 14s 491ms/step - loss: 0.0010 - dice_coef: 0.9993 - val_loss: 0.7951 - val_dice_coef: 0.9286
# Epoch 2/100
# 4/4 [==============================] - 2s 476ms/step - loss: 9.1014e-04 - dice_coef: 0.9993 - val_loss: 0.8004 - val_dice_coef: 0.9285
# Epoch 3/100
# 4/4 [==============================] - 2s 478ms/step - loss: 6.7174e-04 - dice_coef: 0.9994 - val_loss: 0.7804 - val_dice_coef: 0.9300
# Epoch 4/100
# 4/4 [==============================] - 2s 483ms/step - loss: 6.6046e-04 - dice_coef: 0.9995 - val_loss: 0.7955 - val_dice_coef: 0.9291
# Epoch 5/100
# 4/4 [==============================] - 2s 477ms/step - loss: 5.2996e-04 - dice_coef: 0.9995 - val_loss: 0.7971 - val_dice_coef: 0.9291
# Epoch 6/100
# 4/4 [==============================] - 2s 478ms/step - loss: 4.7513e-04 - dice_coef: 0.9996 - val_loss: 0.7920 - val_dice_coef: 0.9295
# Epoch 7/100
# 4/4 [==============================] - 2s 479ms/step - loss: 4.3754e-04 - dice_coef: 0.9996 - val_loss: 0.7965 - val_dice_coef: 0.9292
# Epoch 8/100
# 4/4 [==============================] - 2s 479ms/step - loss: 4.1166e-04 - dice_coef: 0.9996 - val_loss: 0.7964 - val_dice_coef: 0.9292
# Epoch 9/100
# 4/4 [==============================] - 2s 483ms/step - loss: 4.3396e-04 - dice_coef: 0.9996 - val_loss: 0.7944 - val_dice_coef: 0.9294
# Epoch 10/100
# 4/4 [==============================] - 2s 484ms/step - loss: 3.8386e-04 - dice_coef: 0.9996 - val_loss: 0.7944 - val_dice_coef: 0.9295
# Epoch 11/100
# 4/4 [==============================] - 2s 480ms/step - loss: 4.1198e-04 - dice_coef: 0.9996 - val_loss: 0.7979 - val_dice_coef: 0.9293
# Epoch 12/100
# 4/4 [==============================] - 2s 478ms/step - loss: 3.6408e-04 - dice_coef: 0.9997 - val_loss: 0.7986 - val_dice_coef: 0.9293
# Epoch 13/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.6564e-04 - dice_coef: 0.9997 - val_loss: 0.7963 - val_dice_coef: 0.9295
# Epoch 14/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.6128e-04 - dice_coef: 0.9997 - val_loss: 0.7982 - val_dice_coef: 0.9295
# Epoch 15/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.5747e-04 - dice_coef: 0.9997 - val_loss: 0.7998 - val_dice_coef: 0.9294
# Epoch 16/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.5319e-04 - dice_coef: 0.9997 - val_loss: 0.8007 - val_dice_coef: 0.9294
# Epoch 17/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.5255e-04 - dice_coef: 0.9997 - val_loss: 0.8015 - val_dice_coef: 0.9294
# Epoch 18/100
# 4/4 [==============================] - 2s 479ms/step - loss: 3.7202e-04 - dice_coef: 0.9997 - val_loss: 0.8014 - val_dice_coef: 0.9294
# Epoch 19/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.6661e-04 - dice_coef: 0.9996 - val_loss: 0.8031 - val_dice_coef: 0.9294
# Epoch 20/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.2913e-04 - dice_coef: 0.9997 - val_loss: 0.7982 - val_dice_coef: 0.9298
# Epoch 21/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.5029e-04 - dice_coef: 0.9997 - val_loss: 0.8030 - val_dice_coef: 0.9295
# Epoch 22/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.3098e-04 - dice_coef: 0.9997 - val_loss: 0.8016 - val_dice_coef: 0.9297
# Epoch 23/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.3543e-04 - dice_coef: 0.9997 - val_loss: 0.8011 - val_dice_coef: 0.9298
# Epoch 24/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.2544e-04 - dice_coef: 0.9997 - val_loss: 0.8011 - val_dice_coef: 0.9299
# Epoch 25/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.2565e-04 - dice_coef: 0.9997 - val_loss: 0.8053 - val_dice_coef: 0.9296
# Epoch 26/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.0696e-04 - dice_coef: 0.9997 - val_loss: 0.8033 - val_dice_coef: 0.9298
# Epoch 27/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.1309e-04 - dice_coef: 0.9997 - val_loss: 0.8003 - val_dice_coef: 0.9300
# Epoch 28/100
# 4/4 [==============================] - 2s 482ms/step - loss: 3.6044e-04 - dice_coef: 0.9997 - val_loss: 0.8031 - val_dice_coef: 0.9299
# Epoch 29/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.3809e-04 - dice_coef: 0.9997 - val_loss: 0.8052 - val_dice_coef: 0.9297
# Epoch 30/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.3021e-04 - dice_coef: 0.9997 - val_loss: 0.8001 - val_dice_coef: 0.9302
# Epoch 31/100
# 4/4 [==============================] - 2s 482ms/step - loss: 3.1409e-04 - dice_coef: 0.9997 - val_loss: 0.8054 - val_dice_coef: 0.9299
# Epoch 32/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.1497e-04 - dice_coef: 0.9997 - val_loss: 0.8064 - val_dice_coef: 0.9299
# Epoch 33/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.3395e-04 - dice_coef: 0.9997 - val_loss: 0.8055 - val_dice_coef: 0.9300
# Epoch 34/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.0445e-04 - dice_coef: 0.9997 - val_loss: 0.8035 - val_dice_coef: 0.9302
# Epoch 35/100
# 4/4 [==============================] - 2s 482ms/step - loss: 3.0802e-04 - dice_coef: 0.9997 - val_loss: 0.8058 - val_dice_coef: 0.9301
# Epoch 36/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.0920e-04 - dice_coef: 0.9997 - val_loss: 0.8046 - val_dice_coef: 0.9302
# Epoch 37/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.8837e-04 - dice_coef: 0.9997 - val_loss: 0.8012 - val_dice_coef: 0.9304
# Epoch 38/100
# 4/4 [==============================] - 2s 480ms/step - loss: 3.0071e-04 - dice_coef: 0.9997 - val_loss: 0.8034 - val_dice_coef: 0.9303
# Epoch 39/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.9854e-04 - dice_coef: 0.9997 - val_loss: 0.8050 - val_dice_coef: 0.9302
# Epoch 40/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.8993e-04 - dice_coef: 0.9997 - val_loss: 0.8050 - val_dice_coef: 0.9303
# Epoch 41/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.8633e-04 - dice_coef: 0.9997 - val_loss: 0.8054 - val_dice_coef: 0.9303
# Epoch 42/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.8387e-04 - dice_coef: 0.9997 - val_loss: 0.8057 - val_dice_coef: 0.9304
# Epoch 43/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.8630e-04 - dice_coef: 0.9997 - val_loss: 0.8075 - val_dice_coef: 0.9303
# Epoch 44/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.8113e-04 - dice_coef: 0.9997 - val_loss: 0.8079 - val_dice_coef: 0.9303
# Epoch 45/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.7634e-04 - dice_coef: 0.9997 - val_loss: 0.8072 - val_dice_coef: 0.9303
# Epoch 46/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.7140e-04 - dice_coef: 0.9997 - val_loss: 0.8052 - val_dice_coef: 0.9304
# Epoch 47/100
# 4/4 [==============================] - 2s 480ms/step - loss: 2.8429e-04 - dice_coef: 0.9997 - val_loss: 0.8063 - val_dice_coef: 0.9304
# Epoch 48/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.7353e-04 - dice_coef: 0.9997 - val_loss: 0.8091 - val_dice_coef: 0.9303
# Epoch 49/100
# 4/4 [==============================] - 2s 480ms/step - loss: 2.6700e-04 - dice_coef: 0.9997 - val_loss: 0.8092 - val_dice_coef: 0.9303
# Epoch 50/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.8683e-04 - dice_coef: 0.9997 - val_loss: 0.8059 - val_dice_coef: 0.9305
# Epoch 51/100
# 4/4 [==============================] - 2s 481ms/step - loss: 3.0066e-04 - dice_coef: 0.9997 - val_loss: 0.8068 - val_dice_coef: 0.9304
# Epoch 52/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.6374e-04 - dice_coef: 0.9998 - val_loss: 0.8088 - val_dice_coef: 0.9304
# Epoch 53/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.6380e-04 - dice_coef: 0.9998 - val_loss: 0.8078 - val_dice_coef: 0.9305
# Epoch 54/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.7737e-04 - dice_coef: 0.9997 - val_loss: 0.8058 - val_dice_coef: 0.9306
# Epoch 55/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.5855e-04 - dice_coef: 0.9998 - val_loss: 0.8110 - val_dice_coef: 0.9304
# Epoch 56/100
# 4/4 [==============================] - 2s 480ms/step - loss: 2.6971e-04 - dice_coef: 0.9997 - val_loss: 0.8117 - val_dice_coef: 0.9304
# Epoch 57/100
# 4/4 [==============================] - 2s 483ms/step - loss: 2.7413e-04 - dice_coef: 0.9997 - val_loss: 0.8085 - val_dice_coef: 0.9306
# Epoch 58/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.8049e-04 - dice_coef: 0.9997 - val_loss: 0.8107 - val_dice_coef: 0.9305
# Epoch 59/100
# 4/4 [==============================] - 2s 483ms/step - loss: 2.6336e-04 - dice_coef: 0.9997 - val_loss: 0.8127 - val_dice_coef: 0.9304
# Epoch 60/100
# 4/4 [==============================] - 2s 485ms/step - loss: 2.7142e-04 - dice_coef: 0.9997 - val_loss: 0.8105 - val_dice_coef: 0.9307
# Epoch 61/100
# 4/4 [==============================] - 2s 493ms/step - loss: 2.6108e-04 - dice_coef: 0.9998 - val_loss: 0.8109 - val_dice_coef: 0.9307
# Epoch 62/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.5976e-04 - dice_coef: 0.9998 - val_loss: 0.8141 - val_dice_coef: 0.9305
# Epoch 63/100
# 4/4 [==============================] - 2s 484ms/step - loss: 2.5301e-04 - dice_coef: 0.9998 - val_loss: 0.8130 - val_dice_coef: 0.9306
# Epoch 64/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.5042e-04 - dice_coef: 0.9998 - val_loss: 0.8120 - val_dice_coef: 0.9308
# Epoch 65/100
# 4/4 [==============================] - 2s 492ms/step - loss: 2.6347e-04 - dice_coef: 0.9997 - val_loss: 0.8164 - val_dice_coef: 0.9306
# Epoch 66/100
# 4/4 [==============================] - 2s 487ms/step - loss: 2.5378e-04 - dice_coef: 0.9998 - val_loss: 0.8196 - val_dice_coef: 0.9304
# Epoch 67/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.5688e-04 - dice_coef: 0.9998 - val_loss: 0.8124 - val_dice_coef: 0.9308
# Epoch 68/100
# 4/4 [==============================] - 2s 484ms/step - loss: 2.4842e-04 - dice_coef: 0.9998 - val_loss: 0.8138 - val_dice_coef: 0.9308
# Epoch 69/100
# 4/4 [==============================] - 2s 489ms/step - loss: 2.3805e-04 - dice_coef: 0.9998 - val_loss: 0.8171 - val_dice_coef: 0.9306
# Epoch 70/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.4118e-04 - dice_coef: 0.9998 - val_loss: 0.8165 - val_dice_coef: 0.9307
# Epoch 71/100
# 4/4 [==============================] - 2s 487ms/step - loss: 2.3764e-04 - dice_coef: 0.9998 - val_loss: 0.8143 - val_dice_coef: 0.9309
# Epoch 72/100
# 4/4 [==============================] - 2s 487ms/step - loss: 2.5347e-04 - dice_coef: 0.9998 - val_loss: 0.8169 - val_dice_coef: 0.9308
# Epoch 73/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.4899e-04 - dice_coef: 0.9998 - val_loss: 0.8188 - val_dice_coef: 0.9307
# Epoch 74/100
# 4/4 [==============================] - 2s 484ms/step - loss: 2.3786e-04 - dice_coef: 0.9998 - val_loss: 0.8135 - val_dice_coef: 0.9310
# Epoch 75/100
# 4/4 [==============================] - 2s 482ms/step - loss: 2.3929e-04 - dice_coef: 0.9998 - val_loss: 0.8167 - val_dice_coef: 0.9309
# Epoch 76/100
# 4/4 [==============================] - 2s 485ms/step - loss: 2.2619e-04 - dice_coef: 0.9998 - val_loss: 0.8212 - val_dice_coef: 0.9307
# Epoch 77/100
# 4/4 [==============================] - 2s 485ms/step - loss: 2.3752e-04 - dice_coef: 0.9998 - val_loss: 0.8178 - val_dice_coef: 0.9309
# Epoch 78/100
# 4/4 [==============================] - 2s 485ms/step - loss: 2.2958e-04 - dice_coef: 0.9998 - val_loss: 0.8170 - val_dice_coef: 0.9310
# Epoch 79/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.5461e-04 - dice_coef: 0.9998 - val_loss: 0.8232 - val_dice_coef: 0.9307
# Epoch 80/100
# 4/4 [==============================] - 2s 491ms/step - loss: 2.3292e-04 - dice_coef: 0.9998 - val_loss: 0.8207 - val_dice_coef: 0.9309
# Epoch 81/100
# 4/4 [==============================] - 2s 495ms/step - loss: 2.3638e-04 - dice_coef: 0.9998 - val_loss: 0.8187 - val_dice_coef: 0.9310
# Epoch 82/100
# 4/4 [==============================] - 2s 488ms/step - loss: 2.3541e-04 - dice_coef: 0.9998 - val_loss: 0.8229 - val_dice_coef: 0.9308
# Epoch 83/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.3400e-04 - dice_coef: 0.9998 - val_loss: 0.8242 - val_dice_coef: 0.9308
# Epoch 84/100
# 4/4 [==============================] - 2s 487ms/step - loss: 2.5879e-04 - dice_coef: 0.9998 - val_loss: 0.8232 - val_dice_coef: 0.9309
# Epoch 85/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.4417e-04 - dice_coef: 0.9998 - val_loss: 0.8260 - val_dice_coef: 0.9308
# Epoch 86/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.4684e-04 - dice_coef: 0.9998 - val_loss: 0.8245 - val_dice_coef: 0.9309
# Epoch 87/100
# 4/4 [==============================] - 2s 485ms/step - loss: 2.7697e-04 - dice_coef: 0.9997 - val_loss: 0.8248 - val_dice_coef: 0.9309
# Epoch 88/100
# 4/4 [==============================] - 2s 488ms/step - loss: 2.3893e-04 - dice_coef: 0.9998 - val_loss: 0.8272 - val_dice_coef: 0.9308
# Epoch 89/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.3618e-04 - dice_coef: 0.9998 - val_loss: 0.8210 - val_dice_coef: 0.9312
# Epoch 90/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.2263e-04 - dice_coef: 0.9998 - val_loss: 0.8251 - val_dice_coef: 0.9310
# Epoch 91/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.3948e-04 - dice_coef: 0.9998 - val_loss: 0.8301 - val_dice_coef: 0.9308
# Epoch 92/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.2250e-04 - dice_coef: 0.9998 - val_loss: 0.8258 - val_dice_coef: 0.9311
# Epoch 93/100
# 4/4 [==============================] - 2s 488ms/step - loss: 2.1935e-04 - dice_coef: 0.9998 - val_loss: 0.8267 - val_dice_coef: 0.9311
# Epoch 94/100
# 4/4 [==============================] - 2s 491ms/step - loss: 2.2604e-04 - dice_coef: 0.9998 - val_loss: 0.8322 - val_dice_coef: 0.9308
# Epoch 95/100
# 4/4 [==============================] - 2s 495ms/step - loss: 2.1778e-04 - dice_coef: 0.9998 - val_loss: 0.8305 - val_dice_coef: 0.9309
# Epoch 96/100
# 4/4 [==============================] - 2s 488ms/step - loss: 2.3658e-04 - dice_coef: 0.9998 - val_loss: 0.8273 - val_dice_coef: 0.9311
# Epoch 97/100
# 4/4 [==============================] - 2s 481ms/step - loss: 2.2311e-04 - dice_coef: 0.9998 - val_loss: 0.8334 - val_dice_coef: 0.9308
# Epoch 98/100
# 4/4 [==============================] - 2s 488ms/step - loss: 2.2186e-04 - dice_coef: 0.9998 - val_loss: 0.8318 - val_dice_coef: 0.9309
# Epoch 99/100
# 4/4 [==============================] - 2s 490ms/step - loss: 2.1139e-04 - dice_coef: 0.9998 - val_loss: 0.8289 - val_dice_coef: 0.9312
# Epoch 100/100
# 4/4 [==============================] - 2s 486ms/step - loss: 2.1640e-04 - dice_coef: 0.9998 - val_loss: 0.8346 - val_dice_coef: 0.9308

# %%
pred = modelC.predict(xTest)
print(pred.shape)
# Out:
# 2/2 [==============================] - 0s 366ms/step
# (50, 128, 128, 2)

# %%
n = 31
class_ =1
plt.imshow(images[N+n].convert('RGBA'))
plt.title('входной кадр')
plt.show()
plt.imshow(segments[N+n].convert('RGBA'))
plt.title('целевая разметка')
plt.show()
img = yTest[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('целевая разметка класс: '+str(class_))
plt.show()
img = pred[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('предиктивная разметка класс: '+str(class_))
plt.show()
