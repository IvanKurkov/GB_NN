# %% [markdown]
# ## Практическое задание
#
# <ol>
#     <li>Попробуйте обучить нейронную сеть LSTM на любом другом датасете (любимый временной ряд, текст на русском (другом языке) как генератор или классификатор, или прилагаемый набор airline-passengers - пасажиропоток для авиалиний). Опишите, какой результата вы получили? Что помогло вам улучшить ее точность?

# %%
# Рисовать графики сразу же
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import utils
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import tensorflow as tf


from sklearn.preprocessing import StandardScaler
import os
import datetime

# %%
# %load_ext tensorboard

# %%
df = pd.read_csv('airline-passengers.csv')

# %%
df.head(3)
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132

# %%
df.shape
# Out:
# (144, 3)

# %%
df.index = df.Month
df.drop(['Month'],axis = 1,inplace = True)

# %%
df.sort_index(ascending=True, inplace=True)

# %%
df.plot( figsize = (16,5))

plt.grid('On')
plt.show()

# %% [markdown]
# Добавим дату как признаки:
# как "день в году"/366 и (год-1949)

# %%
df['day'] = pd.to_datetime(df.index).dayofyear/366.0
df['year'] = pd.to_datetime(df.index).year - 1949
df.head()
# Out:
#          Passengers       day  year
# Month
# 1949-01         112  0.002732     0
# 1949-02         118  0.087432     0
# 1949-03         132  0.163934     0
# 1949-04         129  0.248634     0
# 1949-05         121  0.330601     0

# %%
data = df.copy()

# %%
scaler = StandardScaler()

# %%
data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns, index=data.index)

# %%
data.head(1)
# Out:
#          Passengers       day      year
# Month
# 1949-01   -1.407779 -1.586596 -1.593255

# %% [markdown]
# ### Важно правильно подготовить датасет для подачи в нейронку

# %% [markdown]
# - Разделим датасет по времени, Трейн предыдущие 70% времени, тест остальные 30%

# %%
train_split = 110 # Берем точку разделения датасета от начала
channelIndexes = [0,1,2]   # список признаков, по которым будем учить
# длина истории для работы
xLen = 7
# отступ тестов от тренировок
bias = 2

# вычисляем точку разделения ряда на тесты и тренировку

# делим
train_data = data.iloc[0 : train_split ,channelIndexes]
val_data = data.iloc[train_split+bias:,channelIndexes]

# %% [markdown]
# - Параметры модели

# %%
# шаг по данным для построения обучающих примеров
step = 1
# длина прошлого 
past = xLen
p = past
# горизонт предсказания
future = 1
h = future

# параметры модели для обучения
learning_rate = 0.001
batch_size = 32
epochs = 1000

# %% [markdown]
# - Выделяем части на обучение и проверку

# %%
Chanel_numb = len(channelIndexes)

start = xLen + future
end = start + train_split-1

xTrain_df = train_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xTrain = xTrain_df[[train_data.columns[i] for i in range(Chanel_numb)]].values
yTrain = train_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее)

sequence_length = int(xLen / step)


x_end = len(val_data) - xLen - future 

label_start = len(train_data)+bias+xLen + future +1

xVal_df = val_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xVal = xVal_df[[val_data.columns[i] for i in range(Chanel_numb)]].values # X_valid - Все столбцы 
yVal = val_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее) (y_valid  только целевой столбез будущего )

# %%
print(xTrain.shape)
print(yTrain.shape)
print(xVal.shape)
print(yVal.shape)
# Out:
# (103, 3)
# (103,)
# (25, 3)
# (25,)

# %%
plt.figure(figsize = (10,5))
plt.plot(data.index[xLen:yTrain.shape[0]+xLen],yTrain[:])
plt.plot(data.index[yTrain.shape[0]+bias+future+2*xLen-1:],yVal[:])
plt.grid()
plt.xlabel('t, дни')
plt.ylabel('$')
plt.title('Passanger')
plt.show()

# %% [markdown]
# - Используем механизм формирования пакетов для обучения

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    xTrain,
    yTrain,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    xVal,
    yVal,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)

# %%
for batch in dataset_val.take(2):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (19, 7, 3)
# Target shape: (19,)

# %% [markdown]
# - Подключим инструмент наблюдения Tensorboard.

# %%
logdir = os.path.join("logs2", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard( logdir, histogram_freq=1)

# %%
callbaсk = EarlyStopping(monitor='val_mae', patience=10)

model = Sequential()

model.add(LSTM(16, input_shape = (inputs.shape[1], inputs.shape[2]), return_sequences="True"))
model.add(Conv1D(8, 7))

model.add(Flatten())                          
     
model.add(Dense(32, activation = "relu")) 
model.add(Dense(1, activation = "linear"))

model.compile(loss = "mse", optimizer = "adam", metrics = ['mae'])

history = model.fit(
    dataset_train,
    epochs = epochs,
    validation_data = dataset_val,
    callbacks = [callbaсk, tensorboard_callback])


plt.plot(history.history['mae'][1:], 
         label = 'Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'][1:], 
         label = 'Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 169ms/step - loss: 0.6402 - mae: 0.6816 - val_loss: 1.5137 - val_mae: 1.0877
# Epoch 2/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5642 - mae: 0.6394 - val_loss: 1.3887 - val_mae: 1.0381
# Epoch 3/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5229 - mae: 0.6142 - val_loss: 1.2616 - val_mae: 0.9856
# Epoch 4/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4861 - mae: 0.5916 - val_loss: 1.1321 - val_mae: 0.9283
# Epoch 5/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4508 - mae: 0.5696 - val_loss: 0.9998 - val_mae: 0.8651
# Epoch 6/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4154 - mae: 0.5478 - val_loss: 0.8667 - val_mae: 0.7949
# Epoch 7/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3798 - mae: 0.5245 - val_loss: 0.7353 - val_mae: 0.7224
# Epoch 8/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.3438 - mae: 0.4990 - val_loss: 0.6079 - val_mae: 0.6524
# Epoch 9/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3075 - mae: 0.4732 - val_loss: 0.4874 - val_mae: 0.5785
# Epoch 10/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2710 - mae: 0.4460 - val_loss: 0.3801 - val_mae: 0.5072
# Epoch 11/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2352 - mae: 0.4155 - val_loss: 0.2931 - val_mae: 0.4496
# Epoch 12/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2011 - mae: 0.3833 - val_loss: 0.2306 - val_mae: 0.4007
# Epoch 13/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0042 - mae: 0.0490 - val_loss: 0.0247 - val_mae: 0.1388
# Epoch 283/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0042 - mae: 0.0489 - val_loss: 0.0247 - val_mae: 0.1387
# Epoch 284/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0042 - mae: 0.0489 - val_loss: 0.0246 - val_mae: 0.1386
# Epoch 285/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0042 - mae: 0.0488 - val_loss: 0.0246 - val_mae: 0.1385
# Epoch 286/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0042 - mae: 0.0487 - val_loss: 0.0245 - val_mae: 0.1384
# Epoch 287/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0042 - mae: 0.0487 - val_loss: 0.0245 - val_mae: 0.1382
# Epoch 288/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0041 - mae: 0.0486 - val_loss: 0.0244 - val_mae: 0.1382
# Epoch 289/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0041 - mae: 0.0486 - val_loss: 0.0244 - val_mae: 0.1381
# Epoch 290/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0041 - mae: 0.0485 - val_loss: 0.0244 - val_mae: 0.1380
# Epoch 291/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0041 - mae: 0.0485 - val_loss: 0.0244 - val_mae: 0.1379
# Epoch 292/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0041 - mae: 0.0484 - val_loss: 0.0243 - val_mae: 0.1378
# Epoch 293/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0041 - mae: 0.0484 - val_loss: 0.0243 - val_mae: 0.1377
# Epoch 294/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0041 - mae: 0.0483 - val_loss: 0.0243 - val_mae: 0.1377
# Epoch 295/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0041 - mae: 0.0483 - val_loss: 0.0242 - val_mae: 0.1375
# Epoch 296/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0040 - mae: 0.0481 - val_loss: 0.0242 - val_mae: 0.1375
# Epoch 297/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0040 - mae: 0.0483 - val_loss: 0.0241 - val_mae: 0.1373
# Epoch 298/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0040 - mae: 0.0481 - val_loss: 0.0241 - val_mae: 0.1372
# Epoch 299/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0040 - mae: 0.0484 - val_loss: 0.0240 - val_mae: 0.1371
# Epoch 300/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0241 - val_mae: 0.1371
# Epoch 301/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0040 - mae: 0.0488 - val_loss: 0.0239 - val_mae: 0.1369
# Epoch 302/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0040 - mae: 0.0488 - val_loss: 0.0242 - val_mae: 0.1372
# Epoch 303/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0041 - mae: 0.0494 - val_loss: 0.0238 - val_mae: 0.1370
# Epoch 304/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0041 - mae: 0.0493 - val_loss: 0.0245 - val_mae: 0.1375
# Epoch 305/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0040 - mae: 0.0493 - val_loss: 0.0239 - val_mae: 0.1374
# Epoch 306/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0040 - mae: 0.0486 - val_loss: 0.0247 - val_mae: 0.1379
# Epoch 307/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0039 - mae: 0.0479 - val_loss: 0.0240 - val_mae: 0.1377
# Epoch 308/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0039 - mae: 0.0476 - val_loss: 0.0244 - val_mae: 0.1379
# Epoch 309/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0039 - mae: 0.0473 - val_loss: 0.0242 - val_mae: 0.1378
# Epoch 310/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0039 - mae: 0.0477 - val_loss: 0.0241 - val_mae: 0.1376
# Epoch 311/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0039 - mae: 0.0474 - val_loss: 0.0242 - val_mae: 0.1376

# %% [markdown]
# Проверяем результаты:
#
# - строим предсказание
# - рисуем прогноз для тестовой части
# - рисуем прогноз по тренировочной части

# %%
pred = model.predict(dataset_train).flatten()
predVal = model.predict(dataset_val).flatten()
# Out:
# 4/4 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 37ms/step

# %% [markdown]
# - Визуализация прогноза на тестовых

# %%
start = 0
step = 150
plt.figure(figsize=(10,5))
plt.grid('on')
plt.plot(predVal[start:start+step], 
         label = 'Прогноз')
plt.plot(yVal.flatten()[start:start+step], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение ')

plt.legend()
plt.show()

# %% [markdown]
# - Визуализация на трейн данных

# %%
start = 0


plt.figure(figsize = (10,5))
plt.grid('on')
plt.plot(pred[start:train_split], 
         label = 'Прогноз')
plt.plot(yTrain.flatten()[start:train_split], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение Close')
plt.legend()
plt.show()

# %% [markdown]
# - Лаговая корреляция

# %%
def correlate(a, b):
    ma = a.mean()
    mb = b.mean()
    mab = (a*b).mean()
    sa = a.std()
    sb = b.std()

    val = 0
    if ((sa>0) & (sb>0)):
        val = (mab-ma*mb)/(sa*sb)
    return val

# %%
corr = []
start = 0 # начальная точка для проверки корреляций рядов
step = 15 # число точек для проверки корреляций рядов
h=0
yLen = yVal.shape[0]
yValF = yVal[start:start+step].flatten() # ряд истиных значений
yPredVal = predVal[start:start+step] # ряд предсказаний 
# смотрим лаговые корреляции yValF[:-i], yPredVal[i:] для лагов от 0 до 5
for i in range(7):
    corr.append(correlate(yValF[:-1-i], yPredVal[i:-1]))
  
plt.plot(corr,label = 'Корреляция')
plt.xlabel('лаговое расстояние между рядами')
plt.ylabel('Значение корреляции')
plt.legend()
plt.show()

# %% [markdown]
# ## Итог:
# - Очень мало данных, сеть моментально переобучается.
# - Очень сильно влиял размер окна времени при формировании данных.
# - Увеличение или добавление новых слоев сразу приводило к переобучению
# - Уменьшение LSTM слоя и добавление Conv1d слоя помогло увеличить качество.
# - Сильно помогло на полносвязном слое изменять функцию активации на Relu

# %% [markdown]
# ## Попробуем для закрепления взять исторические данные с биржи, по стоимости биткоина.

# %%
df = pd.read_csv('BTC_USD.csv')

# %%
df.shape
# Out:
# (299, 7)

# %%
df.head(3)
# Out:
#          Дата      Цена     Откр.     Макс.      Мин.  Объём  Изм. %
# 0  26.10.2022  20.861,0  20.104,0  21.011,0  20.077,0  5,27K   3,77%
# 1  25.10.2022  20.104,0  19.340,0  20.430,0  19.254,0  2,76K   3,95%
# 2  24.10.2022  19.340,0  19.585,0  19.601,0  19.175,0  1,31K  -1,25%

# %%
df['Цена'] = df['Цена'].apply(lambda x: x[:-2])

# %%
df['Откр.'] = df['Откр.'].apply(lambda x: x[:-2])

# %%
df['Макс.'] = df['Макс.'].apply(lambda x: x[:-2])

# %%
df['Мин.'] = df['Мин.'].apply(lambda x: x[:-2])

# %%
df['Объём'] = df['Объём'].apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Изм. %'] = df['Изм. %'].apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Дата'] = pd.to_datetime(df['Дата'])
df.index = df['Дата']
df.drop(['Дата'],axis = 1,inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '31.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '31.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '31.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '31.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '31.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '30.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '29.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '28.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '27.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '26.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '25.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '24.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '23.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '22.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '21.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '20.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '19.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '18.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '17.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '16.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '15.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '14.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_5172\3306576554.py:1: UserWarning: Parsing '13.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])

# %%
df = df.astype(float)

# %%
df.sort_index(ascending=True, inplace=True)

# %%
df.head(1)
# Out:
#               Цена   Откр.   Макс.    Мин.  Объём  Изм. %
# Дата
# 2022-01-01  47.755  46.218  47.954  46.215   2.18    3.33

# %%
df['Цена'].plot( figsize = (16,5))

plt.grid('On')
plt.show()

# %%
df['day'] = pd.to_datetime(df.index).dayofyear/366.0
df['month'] = pd.to_datetime(df.index).month / 12
df['w_d'] = pd.to_datetime(df.index).dayofyear % 7
df.head()
# Out:
#               Цена   Откр.   Макс.    Мин.  Объём  Изм. %       day     month  \
# Дата
# 2022-01-01  47.755  46.218  47.954  46.215   2.18    3.33  0.002732  0.083333
# 2022-01-02  38.733  38.495  39.350  38.039   4.29    0.54  0.005464  0.083333
# 2022-01-03  44.442  43.202  44.939  42.878   6.34    2.87  0.008197  0.083333
# 2022-01-04  46.301  45.535  46.717  44.245   3.96    1.68  0.010929  0.083333
# 2022-01-05  38.496  37.662  38.689  37.426   3.06    2.21  0.013661  0.083333
#
#             w_d
# Дата
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    3
# 2022-01-04    4
# 2022-01-05    5

# %%
data = df.copy()

# %% [markdown]
# ### Важно правильно подготовить датасет для подачи в нейронку

# %% [markdown]
# - Разделим датасет по времени, Трейн предыдущие 70% времени, тест остальные 30%

# %%
train_split = 200 # Берем точку разделения датасета от начала
channelIndexes = [0,1,2,3,4,6,7,8]   # список признаков, по которым будем учить
# длина истории для работы
xLen = 7
# отступ тестов от тренировок
bias = 5

# вычисляем точку разделения ряда на тесты и тренировку

# делим
train_data = data.iloc[0 : train_split ,channelIndexes]
val_data = data.iloc[train_split+bias:,channelIndexes]

# %%
scaler = StandardScaler()

# %%
train_data = pd.DataFrame(scaler.fit_transform(train_data), columns=train_data.columns, index=train_data.index)
val_data = pd.DataFrame(scaler.transform(val_data), columns=val_data.columns, index=val_data.index)

# %%
train_data.head(1)
# Out:
#                 Цена     Откр.     Макс.      Мин.     Объём       day  \
# Дата
# 2022-01-01  1.556604  1.383939  1.462831  1.504512 -0.715622 -1.728134
#
#                month       w_d
# Дата
# 2022-01-01 -1.504562 -1.005651

# %% [markdown]
# - Параметры модели

# %%
# шаг по данным для построения обучающих примеров
step = 1
# длина прошлого 
past = xLen
p = past
# горизонт предсказания
future = 1
h = future

# параметры модели для обучения
learning_rate = 0.001
batch_size = 32
epochs = 1000

# %% [markdown]
# - Выделяем части на обучение и проверку

# %%
Chanel_numb = len(channelIndexes)

start = xLen + future
end = start + train_split-1

xTrain_df = train_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xTrain = xTrain_df[[train_data.columns[i] for i in range(Chanel_numb)]].values
yTrain = train_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее)

sequence_length = int(xLen / step)


x_end = len(val_data) - xLen - future 

label_start = len(train_data)+bias+xLen + future +1

xVal_df = val_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xVal = xVal_df[[val_data.columns[i] for i in range(Chanel_numb)]].values # X_valid - Все столбцы 
yVal = val_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее) (y_valid  только целевой столбез будущего )

# %%
print(xTrain.shape)
print(yTrain.shape)
print(xVal.shape)
print(yVal.shape)
# Out:
# (193, 8)
# (193,)
# (87, 8)
# (87,)

# %%
plt.figure(figsize = (10,5))
plt.plot(data.index[xLen:yTrain.shape[0]+xLen],yTrain[:])
plt.plot(data.index[yTrain.shape[0]+bias+future+2*xLen-1:],yVal[:])
plt.grid()
plt.xlabel('t, дни')
plt.ylabel('$')
plt.title('Passanger')
plt.show()

# %% [markdown]
# - Используем механизм формирования пакетов для обучения

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    xTrain,
    yTrain,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    xVal,
    yVal,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)

# %%
for batch in dataset_val.take(2):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 7, 8)
# Target shape: (32,)

# %% [markdown]
# - Подключим инструмент наблюдения Tensorboard.

# %%
logdir = os.path.join("logs2", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard( logdir, histogram_freq=1)

# %%
callbaсk = EarlyStopping(monitor='val_mae', patience=2)

model = Sequential()

model.add(LSTM(32, input_shape = (inputs.shape[1], inputs.shape[2])))
model.add(Flatten())                          
     
model.add(Dense(512, activation = "relu"))
model.add(Dense(1, activation = "linear"))

model.compile(loss = "mse", optimizer = tf.keras.optimizers.Adagrad(lr=0.01, epsilon=1e-08, decay=0.0), metrics = ['mae'])

history = model.fit(
    dataset_train,
    epochs = epochs,
    validation_data = dataset_val,
    callbacks = [callbaсk, tensorboard_callback])


plt.plot(history.history['mae'][1:], 
         label = 'Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'][1:], 
         label = 'Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# C:\Users\user\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adagrad.py:81: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 6/6 [==============================] - 3s 104ms/step - loss: 0.9218 - mae: 0.8733 - val_loss: 1.0939 - val_mae: 1.0141
# Epoch 2/1000
# 6/6 [==============================] - 0s 33ms/step - loss: 0.6587 - mae: 0.7046 - val_loss: 0.7927 - val_mae: 0.8162
# Epoch 3/1000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5468 - mae: 0.6027 - val_loss: 0.6971 - val_mae: 0.6914
# Epoch 4/1000
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4976 - mae: 0.5441 - val_loss: 0.6738 - val_mae: 0.6201
# Epoch 5/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4748 - mae: 0.5124 - val_loss: 0.6688 - val_mae: 0.5817
# Epoch 6/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4611 - mae: 0.4952 - val_loss: 0.6666 - val_mae: 0.5596
# Epoch 7/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4505 - mae: 0.4837 - val_loss: 0.6640 - val_mae: 0.5459
# Epoch 8/1000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4408 - mae: 0.4749 - val_loss: 0.6608 - val_mae: 0.5358
# Epoch 9/1000
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4316 - mae: 0.4673 - val_loss: 0.6576 - val_mae: 0.5272
# Epoch 10/1000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4227 - mae: 0.4604 - val_loss: 0.6542 - val_mae: 0.5194
# Epoch 11/1000
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4139 - mae: 0.4539 - val_loss: 0.6510 - val_mae: 0.5116
# Epoch 12/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4050 - mae: 0.4475 - val_loss: 0.6481 - val_mae: 0.5033
# Epoch 13/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3962 - mae: 0.4414 - val_loss: 0.6456 - val_mae: 0.4949
# Epoch 14/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3874 - mae: 0.4354 - val_loss: 0.6435 - val_mae: 0.4861
# Epoch 15/1000
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3785 - mae: 0.4294 - val_loss: 0.6420 - val_mae: 0.4778
# Epoch 16/1000
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3696 - mae: 0.4233 - val_loss: 0.6405 - val_mae: 0.4699
# Epoch 17/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3608 - mae: 0.4173 - val_loss: 0.6396 - val_mae: 0.4622
# Epoch 18/1000
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3519 - mae: 0.4115 - val_loss: 0.6393 - val_mae: 0.4544
# Epoch 19/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3430 - mae: 0.4056 - val_loss: 0.6395 - val_mae: 0.4468
# Epoch 20/1000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3341 - mae: 0.3995 - val_loss: 0.6402 - val_mae: 0.4396
# Epoch 21/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3251 - mae: 0.3933 - val_loss: 0.6414 - val_mae: 0.4328
# Epoch 22/1000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3163 - mae: 0.3869 - val_loss: 0.6433 - val_mae: 0.4281
# Epoch 23/1000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3076 - mae: 0.3806 - val_loss: 0.6459 - val_mae: 0.4254
# Epoch 24/1000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2991 - mae: 0.3743 - val_loss: 0.6488 - val_mae: 0.4243
# Epoch 25/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2910 - mae: 0.3686 - val_loss: 0.6524 - val_mae: 0.4239
# Epoch 26/1000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2831 - mae: 0.3628 - val_loss: 0.6560 - val_mae: 0.4257
# Epoch 27/1000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2754 - mae: 0.3575 - val_loss: 0.6605 - val_mae: 0.4301

# %% [markdown]
# Проверяем результаты:
#
# - строим предсказание
# - рисуем прогноз для тестовой части
# - рисуем прогноз по тренировочной части

# %%
pred = model.predict(dataset_train).flatten()
predVal = model.predict(dataset_val).flatten()
# Out:
# 6/6 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 8ms/step

# %% [markdown]
# - Визуализация прогноза на тестовых

# %%
start = 0
step = 150
plt.figure(figsize=(10,5))
plt.grid('on')
plt.plot(predVal[start:start+step], 
         label = 'Прогноз')
plt.plot(yVal.flatten()[start:start+step], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение ')

plt.legend()
plt.show()

# %% [markdown]
# - Визуализация на трейн данных

# %%
start = 0


plt.figure(figsize = (10,5))
plt.grid('on')
plt.plot(pred[start:train_split], 
         label = 'Прогноз')
plt.plot(yTrain.flatten()[start:train_split], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение Close')
plt.legend()
plt.show()

# %% [markdown]
# - Лаговая корреляция

# %%
def correlate(a, b):
    ma = a.mean()
    mb = b.mean()
    mab = (a*b).mean()
    sa = a.std()
    sb = b.std()

    val = 0
    if ((sa>0) & (sb>0)):
        val = (mab-ma*mb)/(sa*sb)
    return val

# %%
corr = []
start = 0 # начальная точка для проверки корреляций рядов
step = 50 # число точек для проверки корреляций рядов
h=0
yLen = yVal.shape[0]
yValF = yVal[start:start+step].flatten() # ряд истиных значений
yPredVal = predVal[start:start+step] # ряд предсказаний 
# смотрим лаговые корреляции yValF[:-i], yPredVal[i:] для лагов от 0 до 5
for i in range(7):
    corr.append(correlate(yValF[:-1-i], yPredVal[i:-1]))
  
plt.plot(corr,label = 'Корреляция')
plt.xlabel('лаговое расстояние между рядами')
plt.ylabel('Значение корреляции')
plt.legend()
plt.show()

# %% [markdown]
# #### С этим датасетом сталкиваюсь с тем, что не могу побороть лаговую корреляцию. Перепробовал кучу вариантов, добавлял слои менял размеры, менял количество признаков, по которым учимся..

# %%
fff = keras.preprocessing.timeseries_dataset_from_array(
    xVal,
    targets=None,
    sequence_length = xLen,
    sampling_rate = 5,
    
)

# %%
model.predict(fff)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# array([[1.203185 ],
#        [1.1170672]], dtype=float32)
