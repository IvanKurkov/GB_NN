# %% [markdown]
# ## Практическое задание
#
# <ol>
#     <li>Попробуйте обучить нейронную сеть LSTM на любом другом датасете (любимый временной ряд, текст на русском (другом языке) как генератор или классификатор, или прилагаемый набор airline-passengers - пасажиропоток для авиалиний). Опишите, какой результата вы получили? Что помогло вам улучшить ее точность?

# %%
# Рисовать графики сразу же
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import utils
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import tensorflow as tf


from sklearn.preprocessing import StandardScaler
import os
import datetime

# %%
# %load_ext tensorboard

# %% [markdown]
# ## Попробуем для закрепления взять исторические данные с биржи, по стоимости биткоина.

# %%
df = pd.read_csv('GBP_RUB.csv')

# %%
df.shape
# Out:
# (474, 7)

# %%
df.head(3)
# Out:
#          Дата    Цена   Откр.   Макс.    Мин.  Объём Изм. %
# 0  26.10.2022  71,009  70,459  71,374  70,287    NaN  0,76%
# 1  25.10.2022  70,471  69,179  70,735  69,087    NaN  0,79%
# 2  24.10.2022  69,918  70,022  70,864  68,618    NaN  0,33%

# %%
df['Цена'] = df['Цена'].apply(lambda x: x[:-2]).apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Откр.'] = df['Откр.'].apply(lambda x: x[:-2]).apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Макс.'] = df['Макс.'].apply(lambda x: x[:-2]).apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Мин.'] = df['Мин.'].apply(lambda x: x[:-2]).apply(lambda x: x[:-1].replace(',', '.'))

# %%
df = df.drop('Объём', axis=1)

# %%
df['Изм. %'] = df['Изм. %'].apply(lambda x: x[:-1].replace(',', '.'))

# %%
df['Дата'] = pd.to_datetime(df['Дата'])
df.index = df['Дата']
df.drop(['Дата'],axis = 1,inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.12.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.11.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.10.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.09.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.08.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# ...
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.06.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.06.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.06.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.05.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '31.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '30.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '24.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '23.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '17.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '16.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.02.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '29.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '28.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '27.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '26.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '25.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '22.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '21.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '20.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '19.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '18.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '15.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '14.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])
# C:\Users\user\AppData\Local\Temp\ipykernel_20996\3306576554.py:1: UserWarning: Parsing '13.01.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Дата'] = pd.to_datetime(df['Дата'])

# %%
df = df.astype(float)

# %%
df.sort_index(ascending=True, inplace=True)

# %%
df.head(1)
# Out:
#              Цена  Откр.  Макс.   Мин.  Изм. %
# Дата
# 2021-01-01  100.0  101.0  101.0  101.0   -0.01

# %%
df['Цена'].plot( figsize = (16,5))

plt.grid('On')
plt.show()

# %%
df['day'] = pd.to_datetime(df.index).dayofyear/366.0
df['month'] = pd.to_datetime(df.index).month / 12
df['w_d'] = pd.to_datetime(df.index).dayofyear % 7
df.head()
# Out:
#              Цена  Откр.  Макс.   Мин.  Изм. %       day     month  w_d
# Дата
# 2021-01-01  100.0  101.0  101.0  101.0   -0.01  0.002732  0.083333    1
# 2021-01-02  103.0  103.0  104.0  103.0    0.06  0.005464  0.083333    2
# 2021-01-03  103.0  103.0  104.0  102.0    0.00  0.008197  0.083333    3
# 2021-01-04  105.0  104.0  105.0  103.0    1.19  0.010929  0.083333    4
# 2021-01-06  103.0  104.0  104.0  103.0   -0.19  0.016393  0.083333    6

# %%
df['Цена'].plot( figsize = (16,5))

plt.grid('On')
plt.show()

# %%
df.head(10)
# Out:
#              Цена  Откр.  Макс.   Мин.  Изм. %       day     month  w_d
# Дата
# 2021-01-01  100.0  101.0  101.0  101.0   -0.01  0.002732  0.083333    1
# 2021-01-02  103.0  103.0  104.0  103.0    0.06  0.005464  0.083333    2
# 2021-01-03  103.0  103.0  104.0  102.0    0.00  0.008197  0.083333    3
# 2021-01-04  105.0  104.0  105.0  103.0    1.19  0.010929  0.083333    4
# 2021-01-06  103.0  104.0  104.0  103.0   -0.19  0.016393  0.083333    6
# 2021-01-07  100.0  101.0  101.0  100.0    0.00  0.019126  0.083333    0
# 2021-01-09  100.0  100.0  101.0  100.0   -0.11  0.024590  0.083333    2
# 2021-01-10   98.0   97.0   99.0   97.0    0.54  0.027322  0.083333    3
# 2021-01-11   97.0   97.0   97.0   96.0    0.58  0.030055  0.083333    4
# 2021-01-12   97.0   98.0   99.0   97.0   -0.28  0.032787  0.083333    5

# %%
df['Цена'].plot( figsize = (16,5))

plt.grid('On')
plt.show()

# %%
data = df.iloc[7:].copy()

# %% [markdown]
# ### Важно правильно подготовить датасет для подачи в нейронку

# %% [markdown]
# - Разделим датасет по времени, Трейн предыдущие 70% времени, тест остальные 30%

# %%
train_split = 400 # Берем точку разделения датасета от начала
channelIndexes = [0,1,2,3,4,5,6,7]   # список признаков, по которым будем учить
# длина истории для работы
xLen = 30
# отступ тестов от тренировок
bias = 5

# вычисляем точку разделения ряда на тесты и тренировку

# делим
train_data = data.iloc[225 : train_split ,channelIndexes]
val_data = data.iloc[train_split+bias:,channelIndexes]

# %%
scaler = StandardScaler()

# %%
train_data = pd.DataFrame(scaler.fit_transform(train_data), columns=train_data.columns, index=train_data.index)
val_data = pd.DataFrame(scaler.transform(val_data), columns=val_data.columns, index=val_data.index)

# %%
train_data.head(1)
# Out:
#                 Цена    Откр.    Макс.      Мин.    Изм. %       day  \
# Дата
# 2021-11-24  0.204458  0.18919  0.06488  0.405247  0.082748  1.694406
#
#                month       w_d
# Дата
# 2021-11-24  1.617888  1.268226

# %% [markdown]
# - Параметры модели

# %%
# шаг по данным для построения обучающих примеров
step = 1
# длина прошлого 
past = xLen
p = past
# горизонт предсказания
future = 1
h = future

# параметры модели для обучения
learning_rate = 0.001
batch_size = 32
epochs = 1000

# %% [markdown]
# - Выделяем части на обучение и проверку

# %%
Chanel_numb = len(channelIndexes)

start = xLen + future
end = start + train_split-1

xTrain_df = train_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xTrain = xTrain_df[[train_data.columns[i] for i in range(Chanel_numb)]].values
yTrain = train_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее)

sequence_length = int(xLen / step)


x_end = len(val_data) - xLen - future 

label_start = len(train_data)+bias+xLen + future +1

xVal_df = val_data.iloc[:-future-xLen+1,:] # сдвиг по времени для предсказания (закончить чуть раньше)
xVal = xVal_df[[val_data.columns[i] for i in range(Chanel_numb)]].values # X_valid - Все столбцы 
yVal = val_data.iloc[future+xLen-1:,0].values  # сдвиг по времени для предсказания (начать чуть позднее) (y_valid  только целевой столбез будущего )

# %%
xTrain
# Out:
# array([[-0.06242171, -0.08010642, -0.18666521,  0.1404784 ,  0.08726051,
#          1.57628193,  1.51729476,  1.2581101 ],
#        [-0.06242171, -0.08010642, -0.18666521,  0.1404784 , -0.07868109,
#          1.58457292,  1.51729476, -1.60992204],
#        [-0.01175474, -0.08010642, -0.1421363 ,  0.1404784 ,  0.29035322,
#          1.5928639 ,  1.51729476, -1.13191668],
#        [-0.11308869, -0.03053562, -0.18666521,  0.08309343, -0.3684597 ,
#          1.61773685,  1.51729476,  0.30209938],
#        [-0.11308869, -0.08010642, -0.18666521,  0.08309343, -0.15793677,
#          1.62602784,  1.51729476,  0.78010474],
#        [-0.01175474,  0.01903519, -0.1421363 ,  0.19786336, -0.09106479,
#          1.63431882,  1.77153316,  1.2581101 ],
#        [ 0.03891224,  0.01903519, -0.09760738,  0.25524833,  0.04515593,
#          1.64260981,  1.77153316, -1.60992204],
#        [ 0.03891224,  0.068606  , -0.09760738,  0.25524833, -0.21985528,
#          1.65090079,  1.77153316, -1.13191668],
#        [ 0.29224712,  0.26688922,  0.08050828,  0.48478819,  0.03772571,
#          1.65919177,  1.77153316, -0.65391133],
#        [ 0.19091317,  0.16774761,  0.03597936,  0.42740323,  0.03029549,
#          1.66748276,  1.77153316, -0.17590597],
#        [ 0.14024619,  0.1181768 , -0.05307847,  0.31263329, -0.01428584,
#          1.68406473,  1.77153316,  0.78010474],
#        [ 0.03891224,  0.01903519, -0.09760738,  0.25524833, -0.0613439 ,
#          1.69235571,  1.77153316,  1.2581101 ],
#        [-0.16375567, -0.17924804, -0.27572304,  0.02570846,  0.02781875,
#          1.70893768,  1.77153316, -1.13191668],
#        [-0.16375567, -0.27838965, -0.27572304, -0.08906147,  0.55536443,
#          1.71722866,  1.77153316, -0.65391133],
#        [-0.21442264, -0.17924804, -0.32025195, -0.0316765 , -0.02914628,
#          1.73381063,  1.77153316,  0.30209938],
#        [-0.16375567, -0.17924804, -0.32025195, -0.0316765 ,  0.1665162 ,
#          1.74210162,  1.77153316,  0.78010474],
#        [-0.16375567, -0.17924804, -0.27572304,  0.02570846, -0.01923932,
#          1.7503926 ,  1.77153316,  1.2581101 ],
#        [-0.11308869, -0.17924804, -0.27572304,  0.02570846,  0.16899294,
#         -0.40526331, -0.51661243,  0.78010474],
#        [ 0.3429141 ,  0.41560164,  0.43673959,  0.31263329, -0.50220368,
#         -0.39697233, -0.51661243,  1.2581101 ],
#        [ 0.03891224, -0.03053562, -0.09760738,  0.19786336,  0.47858548,
#         -0.38868134, -0.26237403, -1.60992204],
#        [ 0.08957921,  0.1181768 , -0.00854955,  0.31263329, -0.22976224,
#         -0.38039036, -0.26237403, -1.13191668],
#        [ 3.12959779,  2.24972147,  2.8858299 ,  2.09156724,  2.60610539,
#         -0.37209937, -0.26237403, -0.65391133],
#        [ 0.49491502,  0.86173889,  0.70391308,  0.42740323, -0.49477345,
#         -0.36380839, -0.26237403, -0.17590597],
#        [-0.87309333, -0.77409771, -0.81007001, -1.00722092, -0.52449434,
#         -0.35551741, -0.26237403,  0.30209938],
#        [-1.68376495, -1.76551383, -1.34441699, -1.92538038,  0.94668939,
#         -0.33893544, -0.26237403,  1.2581101 ],
#        [-1.27842914, -1.31937658, -1.25535916, -1.46630065,  0.35227173,
#         -0.33064445, -0.26237403, -1.60992204],
#        [-1.68376495, -1.76551383, -1.56706156, -1.81061045,  0.7807478 ,
#         -0.31406248, -0.26237403, -0.65391133]])

# %%
print(xTrain.shape)
print(yTrain.shape)
print(xVal.shape)
print(yVal.shape)
# Out:
# (145, 8)
# (145,)
# (32, 8)
# (32,)

# %%
plt.figure(figsize = (10,5))
plt.plot(data.index[150:350],yTrain[:])
plt.plot(data.index[yTrain.shape[0]+bias+future+2*xLen-1:],yVal[:])
plt.grid()
plt.xlabel('t, дни')
plt.ylabel('$')
plt.title('Passanger')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       1 plt.figure(figsize = (10,5))
# ----> 2 plt.plot(data.index[150:350],yTrain[:])
#       3 plt.plot(data.index[yTrain.shape[0]+bias+future+2*xLen-1:],yVal[:])
#       4 plt.grid()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (145,)

# %% [markdown]
# - Используем механизм формирования пакетов для обучения

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    xTrain,
    yTrain,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    xVal,
    yVal,
    sequence_length = xLen,
    sampling_rate = 1,
    batch_size = batch_size,
)

# %%
dataset_train
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, None, 8), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>

# %%
for batch in dataset_val.take(2):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (3, 30, 8)
# Target shape: (3,)

# %% [markdown]
# - Подключим инструмент наблюдения Tensorboard.

# %%
logdir = os.path.join("logs2", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard( logdir, histogram_freq=1)

# %%
(inputs.shape[1], inputs.shape[2])
# Out:
# (30, 8)

# %%
callbaсk = EarlyStopping(monitor='val_mae', patience=2)

model = Sequential()

model.add(LSTM(30, input_shape = (inputs.shape[1], inputs.shape[2]), return_sequences="False"))
model.add(Flatten())                          
     
model.add(Dense(512, activation = "relu"))
model.add(Dense(1, activation = "linear"))

model.compile(loss = "mse", optimizer = tf.keras.optimizers.Adagrad(lr=0.01, epsilon=1e-08, decay=0.0), metrics = ['mae'])

history = model.fit(
    dataset_train,
    epochs = epochs,
    validation_data = dataset_val,
    callbacks = [callbaсk, tensorboard_callback])


plt.plot(history.history['mae'][1:], 
         label = 'Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'][1:], 
         label = 'Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# C:\Users\user\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adagrad.py:81: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 4/4 [==============================] - 2s 191ms/step - loss: 1.1042 - mae: 0.8864 - val_loss: 7.1706 - val_mae: 2.2485
# Epoch 2/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6754 - mae: 0.5868 - val_loss: 7.1686 - val_mae: 2.2551
# Epoch 3/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5689 - mae: 0.5295 - val_loss: 7.0263 - val_mae: 2.2279
# Epoch 4/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5064 - mae: 0.4950 - val_loss: 6.8863 - val_mae: 2.2009
# Epoch 5/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4604 - mae: 0.4680 - val_loss: 6.7848 - val_mae: 2.1818
# Epoch 6/1000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.4257 - mae: 0.4453 - val_loss: 6.6707 - val_mae: 2.1583
# Epoch 7/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.3972 - mae: 0.4247 - val_loss: 6.5806 - val_mae: 2.1399
# Epoch 8/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3740 - mae: 0.4066 - val_loss: 6.5011 - val_mae: 2.1236
# Epoch 9/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3532 - mae: 0.3908 - val_loss: 6.4253 - val_mae: 2.1079
# Epoch 10/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3348 - mae: 0.3770 - val_loss: 6.3312 - val_mae: 2.0881
# Epoch 11/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3182 - mae: 0.3635 - val_loss: 6.2444 - val_mae: 2.0696
# Epoch 12/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3032 - mae: 0.3518 - val_loss: 6.1875 - val_mae: 2.0578
# Epoch 13/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.2897 - mae: 0.3399 - val_loss: 6.1079 - val_mae: 2.0396
# Epoch 14/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.2773 - mae: 0.3292 - val_loss: 6.0411 - val_mae: 2.0249
# Epoch 15/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2656 - mae: 0.3189 - val_loss: 5.9971 - val_mae: 2.0146
# Epoch 16/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2547 - mae: 0.3085 - val_loss: 5.9141 - val_mae: 1.9957
# Epoch 17/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2448 - mae: 0.2996 - val_loss: 5.8627 - val_mae: 1.9831
# Epoch 18/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.2351 - mae: 0.2912 - val_loss: 5.7941 - val_mae: 1.9667
# Epoch 19/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.2260 - mae: 0.2831 - val_loss: 5.7449 - val_mae: 1.9544
# Epoch 20/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2176 - mae: 0.2754 - val_loss: 5.6880 - val_mae: 1.9410
# Epoch 21/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2094 - mae: 0.2693 - val_loss: 5.6494 - val_mae: 1.9319
# Epoch 22/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2014 - mae: 0.2636 - val_loss: 5.5991 - val_mae: 1.9191
# Epoch 23/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1939 - mae: 0.2587 - val_loss: 5.5679 - val_mae: 1.9115
# Epoch 24/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.1869 - mae: 0.2524 - val_loss: 5.5014 - val_mae: 1.8953
# Epoch 25/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.1803 - mae: 0.2481 - val_loss: 5.4835 - val_mae: 1.8908
# Epoch 26/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.1740 - mae: 0.2439 - val_loss: 5.4236 - val_mae: 1.8764
# Epoch 27/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1679 - mae: 0.2382 - val_loss: 5.3721 - val_mae: 1.8626
# Epoch 28/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1617 - mae: 0.2357 - val_loss: 5.3692 - val_mae: 1.8618
# Epoch 29/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.1562 - mae: 0.2300 - val_loss: 5.2670 - val_mae: 1.8351
# Epoch 30/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1508 - mae: 0.2286 - val_loss: 5.2860 - val_mae: 1.8410
# Epoch 31/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1458 - mae: 0.2226 - val_loss: 5.1799 - val_mae: 1.8132
# Epoch 32/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1407 - mae: 0.2215 - val_loss: 5.2019 - val_mae: 1.8192
# Epoch 33/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.1362 - mae: 0.2159 - val_loss: 5.0918 - val_mae: 1.7893
# Epoch 34/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.1315 - mae: 0.2155 - val_loss: 5.1468 - val_mae: 1.8055
# Epoch 35/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1277 - mae: 0.2103 - val_loss: 5.0120 - val_mae: 1.7689
# Epoch 36/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.1232 - mae: 0.2107 - val_loss: 5.0941 - val_mae: 1.7914
# Epoch 37/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.1200 - mae: 0.2057 - val_loss: 4.8928 - val_mae: 1.7363
# Epoch 38/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.1162 - mae: 0.2085 - val_loss: 5.0572 - val_mae: 1.7818
# Epoch 39/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.1136 - mae: 0.2027 - val_loss: 4.8139 - val_mae: 1.7150
# Epoch 40/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.1098 - mae: 0.2059 - val_loss: 5.0417 - val_mae: 1.7783
# Epoch 41/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1084 - mae: 0.2011 - val_loss: 4.7065 - val_mae: 1.6841
# Epoch 42/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.1061 - mae: 0.2091 - val_loss: 5.0643 - val_mae: 1.7841
# Epoch 43/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1070 - mae: 0.2039 - val_loss: 4.5889 - val_mae: 1.6492
# Epoch 44/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1063 - mae: 0.2175 - val_loss: 5.1099 - val_mae: 1.7977
# Epoch 45/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1111 - mae: 0.2129 - val_loss: 4.4723 - val_mae: 1.6146
# Epoch 46/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1116 - mae: 0.2326 - val_loss: 5.1981 - val_mae: 1.8213
# Epoch 47/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.1186 - mae: 0.2250 - val_loss: 4.3983 - val_mae: 1.5918
# Epoch 48/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1184 - mae: 0.2458 - val_loss: 5.2620 - val_mae: 1.8384
# Epoch 49/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1217 - mae: 0.2303 - val_loss: 4.3945 - val_mae: 1.5895
# Epoch 50/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1131 - mae: 0.2405 - val_loss: 5.2374 - val_mae: 1.8313
# Epoch 51/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.1077 - mae: 0.2151 - val_loss: 4.4452 - val_mae: 1.6031

# %% [markdown]
# Проверяем результаты:
#
# - строим предсказание
# - рисуем прогноз для тестовой части
# - рисуем прогноз по тренировочной части

# %%
pred = model.predict(dataset_train).flatten()
predVal = model.predict(dataset_val).flatten()
# Out:
# 4/4 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 38ms/step

# %% [markdown]
# - Визуализация прогноза на тестовых

# %%
start = 0
step = 225
plt.figure(figsize=(10,5))
plt.grid('on')
plt.plot(predVal[start:start+step], 
         label = 'Прогноз')
plt.plot(yVal.flatten()[start:start+step], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение ')

plt.legend()
plt.show()

# %% [markdown]
# - Визуализация на трейн данных

# %%
start = 0


plt.figure(figsize = (10,5))
plt.grid('on')
plt.plot(pred[start:train_split], 
         label = 'Прогноз')
plt.plot(yTrain.flatten()[start:train_split], 
         label = 'Базовый ряд')
plt.xlabel('Время')
plt.ylabel('Значение Close')
plt.legend()
plt.show()

# %% [markdown]
# - Лаговая корреляция

# %%
def correlate(a, b):
    ma = a.mean()
    mb = b.mean()
    mab = (a*b).mean()
    sa = a.std()
    sb = b.std()

    val = 0
    if ((sa>0) & (sb>0)):
        val = (mab-ma*mb)/(sa*sb)
    return val

# %%
corr = []
start = 0 # начальная точка для проверки корреляций рядов
step = 5 # число точек для проверки корреляций рядов
h=0
yLen = yVal.shape[0]
yValF = yVal[start:start+step].flatten() # ряд истиных значений
yPredVal = predVal[start:start+step] # ряд предсказаний 
# смотрим лаговые корреляции yValF[:-i], yPredVal[i:] для лагов от 0 до 5
for i in range(7):
    corr.append(correlate(yValF[:-1-i], yPredVal[i:-1]))
  
plt.plot(corr,label = 'Корреляция')
plt.xlabel('лаговое расстояние между рядами')
plt.ylabel('Значение корреляции')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [89], in <cell line: 9>()
#       8 # смотрим лаговые корреляции yValF[:-i], yPredVal[i:] для лагов от 0 до 5
#       9 for i in range(7):
# ---> 10     corr.append(correlate(yValF[:-1-i], yPredVal[i:-1]))
#      12 plt.plot(corr,label = 'Корреляция')
#      13 plt.xlabel('лаговое расстояние между рядами')
#
# Input In [86], in correlate(a, b)
#       2 ma = a.mean()
#       3 mb = b.mean()
# ----> 4 mab = (a*b).mean()
#       5 sa = a.std()
#       6 sb = b.std()
#
# ValueError: operands could not be broadcast together with shapes (4,) (2,)

# %% [markdown]
# #### С этим датасетом сталкиваюсь с тем, что не могу побороть лаговую корреляцию. Перепробовал кучу вариантов, добавлял слои менял размеры, менял количество признаков, по которым учимся..

# %%
fff = keras.preprocessing.timeseries_dataset_from_array(
    xVal,
    targets=None,
    sequence_length = xLen,
    sampling_rate = 5,
    
)

# %%
model.predict(fff)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# array([[1.203185 ],
#        [1.1170672]], dtype=float32)
